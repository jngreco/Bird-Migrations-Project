# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %%
BE_df = pd.read_csv('baldeagle.txt', delimiter = "\t")
BE_df.head()
# Out:
# C:\Users\Connor Thomas\AppData\Local\Temp\ipykernel_11660\1432571989.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   BE_df = pd.read_csv('baldeagle.txt', delimiter = "\t")
#                          GLOBAL UNIQUE IDENTIFIER            LAST EDITED DATE  \
# 0  URN:CornellLabOfOrnithology:EBIRD:OBS544340737         2017-10-25 17:31:23
# 1  URN:CornellLabOfOrnithology:EBIRD:OBS555939816         2017-12-10 00:23:41
# 2  URN:CornellLabOfOrnithology:EBIRD:OBS706367426  2021-12-09 20:56:19.489766
# 3   URN:CornellLabOfOrnithology:EBIRD:OBS13724601         2013-07-29 15:50:42
# 4   URN:CornellLabOfOrnithology:EBIRD:OBS32408958    2021-04-01 05:24:59.0786
#
#    TAXONOMIC ORDER CATEGORY  TAXON CONCEPT ID COMMON NAME  \
# 0             8105  species  avibase-FED3756C  Bald Eagle
# 1             8105  species  avibase-FED3756C  Bald Eagle
# 2             8105  species  avibase-FED3756C  Bald Eagle
# ...

# %%
BE_df
# Out:
#                                GLOBAL UNIQUE IDENTIFIER  \
# 0        URN:CornellLabOfOrnithology:EBIRD:OBS544340737
# 1        URN:CornellLabOfOrnithology:EBIRD:OBS555939816
# 2        URN:CornellLabOfOrnithology:EBIRD:OBS706367426
# 3         URN:CornellLabOfOrnithology:EBIRD:OBS13724601
# 4         URN:CornellLabOfOrnithology:EBIRD:OBS32408958
# ...                                                 ...
# 111174  URN:CornellLabOfOrnithology:EBIRD:OBS1636556066
# 111175  URN:CornellLabOfOrnithology:EBIRD:OBS1627831129
# 111176  URN:CornellLabOfOrnithology:EBIRD:OBS1621388893
# 111177  URN:CornellLabOfOrnithology:EBIRD:OBS1621251766
# 111178  URN:CornellLabOfOrnithology:EBIRD:OBS1636648427
#
#                   LAST EDITED DATE  TAXONOMIC ORDER CATEGORY  \
# 0              2017-10-25 17:31:23             8105  species
# 1              2017-12-10 00:23:41             8105  species
# 2       2021-12-09 20:56:19.489766             8105  species
# ...

# %%
BBP_df = pd.read_csv('blackbelliedplover.txt', delimiter = "\t")

# %%
BCNH_df = pd.read_csv('blackcrownednightheron.txt', delimiter = "\t")

# %%
DCC_df = pd.read_csv('doublecrestedcormorant.txt', delimiter = "\t")
# Out:
# C:\Users\Connor Thomas\AppData\Local\Temp\ipykernel_11660\2750453740.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   DCC_df = pd.read_csv('doublecrestedcormorant.txt', delimiter = "\t")

# %%
D_df = pd.read_csv('dunlin.txt', delimiter = "\t")

# %%
GHO_df = pd.read_csv('greathornedowl.txt', delimiter = "\t")

# %%
IB_df = pd.read_csv('indigobunting.txt', delimiter = "\t")
# Out:
# C:\Users\Connor Thomas\AppData\Local\Temp\ipykernel_11660\1527827650.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   IB_df = pd.read_csv('indigobunting.txt', delimiter = "\t")

# %%
NH_df = pd.read_csv('northernharrier.txt', delimiter = "\t")

# %%
RHW_df = pd.read_csv('redheadedwoodpecker.txt', delimiter = "\t")
# Out:
# C:\Users\Connor Thomas\AppData\Local\Temp\ipykernel_11660\4009023598.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   RHW_df = pd.read_csv('redheadedwoodpecker.txt', delimiter = "\t")

# %%
ST_df = pd.read_csv('scarlettanager.txt', delimiter = "\t")

# %%
SO_df = pd.read_csv('snowyowl.txt', delimiter = "\t")

# %%
WEW_df = pd.read_csv('wormeatingwarbler.txt', delimiter = "\t")

# %%
bird_df = pd.concat([BE_df,BBP_df,BCNH_df,DCC_df,D_df,GHO_df,IB_df,NH_df,RHW_df,ST_df,SO_df,WEW_df])

# %%
bird_df
# Out:
#                              GLOBAL UNIQUE IDENTIFIER  \
# 0      URN:CornellLabOfOrnithology:EBIRD:OBS544340737
# 1      URN:CornellLabOfOrnithology:EBIRD:OBS555939816
# 2      URN:CornellLabOfOrnithology:EBIRD:OBS706367426
# 3       URN:CornellLabOfOrnithology:EBIRD:OBS13724601
# 4       URN:CornellLabOfOrnithology:EBIRD:OBS32408958
# ...                                               ...
# 3313  URN:CornellLabOfOrnithology:EBIRD:OBS1000989688
# 3314   URN:CornellLabOfOrnithology:EBIRD:OBS255488834
# 3315   URN:CornellLabOfOrnithology:EBIRD:OBS339095262
# 3316   URN:CornellLabOfOrnithology:EBIRD:OBS608688844
# 3317   URN:CornellLabOfOrnithology:EBIRD:OBS918041555
#
#                 LAST EDITED DATE  TAXONOMIC ORDER CATEGORY  TAXON CONCEPT ID  \
# 0            2017-10-25 17:31:23             8105  species  avibase-FED3756C
# 1            2017-12-10 00:23:41             8105  species  avibase-FED3756C
# 2     2021-12-09 20:56:19.489766             8105  species  avibase-FED3756C
# ...

# %%
bird_df.to_csv("birddata.csv")

# %% [markdown]
# <h1>/////START HERE\\\\\</h1>

# %%
bird_df = pd.read_csv("birddata.csv")
# Out:
# C:\Users\Connor Thomas\AppData\Local\Temp\ipykernel_11660\3784647926.py:1: DtypeWarning: Columns (8,9,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   bird_df = pd.read_csv("birddata.csv")

# %%
bird_df = bird_df.reset_index()

# %%
bird_df.columns
# Out:
# Index(['index', 'Unnamed: 0', 'GLOBAL UNIQUE IDENTIFIER', 'LAST EDITED DATE',
#        'TAXONOMIC ORDER', 'CATEGORY', 'TAXON CONCEPT ID', 'COMMON NAME',
#        'SCIENTIFIC NAME', 'SUBSPECIES COMMON NAME',
#        'SUBSPECIES SCIENTIFIC NAME', 'EXOTIC CODE', 'OBSERVATION COUNT',
#        'BREEDING CODE', 'BREEDING CATEGORY', 'BEHAVIOR CODE', 'AGE/SEX',
#        'COUNTRY', 'COUNTRY CODE', 'STATE', 'STATE CODE', 'COUNTY',
#        'COUNTY CODE', 'IBA CODE', 'BCR CODE', 'USFWS CODE', 'ATLAS BLOCK',
#        'LOCALITY', 'LOCALITY ID', 'LOCALITY TYPE', 'LATITUDE', 'LONGITUDE',
#        'OBSERVATION DATE', 'TIME OBSERVATIONS STARTED', 'OBSERVER ID',
#        'SAMPLING EVENT IDENTIFIER', 'PROTOCOL TYPE', 'PROTOCOL CODE',
#        'PROJECT CODE', 'DURATION MINUTES', 'EFFORT DISTANCE KM',
#        'EFFORT AREA HA', 'NUMBER OBSERVERS', 'ALL SPECIES REPORTED',
#        'GROUP IDENTIFIER', 'HAS MEDIA', 'APPROVED', 'REVIEWED', 'REASON',
# ...

# %%
clean_df = bird_df[["COMMON NAME","SCIENTIFIC NAME","OBSERVATION COUNT","COUNTRY","STATE","COUNTY","LOCALITY","LATITUDE","LONGITUDE","OBSERVATION DATE","TIME OBSERVATIONS STARTED","PROTOCOL TYPE","PROTOCOL CODE","REVIEWED"]]

# %%
bird_df["OBSERVATION COUNT"].value_counts()
# Out:
# 1       345526
# 2       133572
# 3        60084
# 4        36881
# X        27783
#          ...
# 219          1
# 652          1
# 428          1
# 1211         1
# 6510         1
# Name: OBSERVATION COUNT, Length: 640, dtype: int64

# %%
clean_df
# Out:
#                 COMMON NAME           SCIENTIFIC NAME OBSERVATION COUNT  \
# 0                Bald Eagle  Haliaeetus leucocephalus                 X
# 1                Bald Eagle  Haliaeetus leucocephalus                 X
# 2                Bald Eagle  Haliaeetus leucocephalus                 1
# 3                Bald Eagle  Haliaeetus leucocephalus                 1
# 4                Bald Eagle  Haliaeetus leucocephalus                 X
# ...                     ...                       ...               ...
# 732908  Worm-eating Warbler    Helmitheros vermivorum                 1
# 732909  Worm-eating Warbler    Helmitheros vermivorum                 1
# 732910  Worm-eating Warbler    Helmitheros vermivorum                 1
# 732911  Worm-eating Warbler    Helmitheros vermivorum                 1
# 732912  Worm-eating Warbler    Helmitheros vermivorum                 1
#
#               COUNTRY     STATE    COUNTY                       LOCALITY  \
# ...

# %%
clean_df["OBSERVATION COUNT"] = clean_df["OBSERVATION COUNT"].replace("X",1)
# Out:
# C:\Users\Connor Thomas\AppData\Local\Temp\ipykernel_11660\121129595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df["OBSERVATION COUNT"] = clean_df["OBSERVATION COUNT"].replace("X",1)

# %%
clean_df["OBSERVATION COUNT"] = clean_df["OBSERVATION COUNT"].astype(int)
# Out:
# C:\Users\Connor Thomas\AppData\Local\Temp\ipykernel_11660\3770564684.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df["OBSERVATION COUNT"] = clean_df["OBSERVATION COUNT"].astype(int)

# %%
year = []
month = []
for date in clean_df["OBSERVATION DATE"]:
    year.append(int(date.split("-")[0]))
    month.append(int(date.split("-")[1]))
clean_df["OBSERVATION YEAR"] = year
clean_df["OBSERVATION MONTH"] = month
clean_df
# Out:
# C:\Users\Connor Thomas\AppData\Local\Temp\ipykernel_11660\497406604.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df["OBSERVATION YEAR"] = year
# C:\Users\Connor Thomas\AppData\Local\Temp\ipykernel_11660\497406604.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df["OBSERVATION MONTH"] = month
#                 COMMON NAME           SCIENTIFIC NAME  OBSERVATION COUNT  \
# 0                Bald Eagle  Haliaeetus leucocephalus                  1
# ...

# %%
def generate_year_plot(bird):
    filter_df = clean_df.loc[clean_df["COMMON NAME"] == bird]
    gf_df = filter_df.groupby(["OBSERVATION YEAR"]).sum()
    plt.figure(figsize=(16,8))
    gf_df["OBSERVATION COUNT"].plot(kind="bar")
    plt.title(f"{bird} Sightings by Year")
    plt.ylabel("Recorded Sightings")
    plt.xlabel("Observation Year")
    plt.show()
    return

# %%
def generate_month_plot(bird):
    filter_df = clean_df.loc[clean_df["COMMON NAME"] == bird]
    gf_df = filter_df.groupby(["OBSERVATION MONTH"]).sum()
    plt.figure(figsize=(8,6))
    gf_df["OBSERVATION COUNT"].plot(kind="bar")
    plt.title(f"{bird} Sightings by Month")
    plt.ylabel("Recorded Sightings")
    plt.xlabel("Observation Month")
    plt.show()
    return

# %%
clean_df["COMMON NAME"].unique()
# Out:
# array(['Bald Eagle', 'Black-bellied Plover', 'Black-crowned Night-Heron',
#        'Double-crested Cormorant', 'Dunlin', 'Great Horned Owl',
#        'Indigo Bunting', 'Northern Harrier', 'Red-headed Woodpecker',
#        'Scarlet Tanager', 'Snowy Owl', 'Worm-eating Warbler'],
#       dtype=object)

# %%
generate_month_plot("Double-crested Cormorant")

# %%
addCol = ["NaN"]*732913
clean_df.insert(16,"STATUS",addCol,True)

# %%
clean_df
# Out:
#                 COMMON NAME           SCIENTIFIC NAME  OBSERVATION COUNT  \
# 0                Bald Eagle  Haliaeetus leucocephalus                  1
# 1                Bald Eagle  Haliaeetus leucocephalus                  1
# 2                Bald Eagle  Haliaeetus leucocephalus                  1
# 3                Bald Eagle  Haliaeetus leucocephalus                  1
# 4                Bald Eagle  Haliaeetus leucocephalus                  1
# ...                     ...                       ...                ...
# 732908  Worm-eating Warbler    Helmitheros vermivorum                  1
# 732909  Worm-eating Warbler    Helmitheros vermivorum                  1
# 732910  Worm-eating Warbler    Helmitheros vermivorum                  1
# 732911  Worm-eating Warbler    Helmitheros vermivorum                  1
# 732912  Worm-eating Warbler    Helmitheros vermivorum                  1
#
#               COUNTRY     STATE    COUNTY                       LOCALITY  \
# ...

# %%
clean_df["COMMON NAME"].unique()
# Out:
# array(['Bald Eagle', 'Black-bellied Plover', 'Black-crowned Night-Heron',
#        'Double-crested Cormorant', 'Dunlin', 'Great Horned Owl',
#        'Indigo Bunting', 'Northern Harrier', 'Red-headed Woodpecker',
#        'Scarlet Tanager', 'Snowy Owl', 'Worm-eating Warbler'],
#       dtype=object)

# %%
clean_df.loc[clean_df["COMMON NAME"] == "Bald Eagle","STATUS"] = "Stable"
clean_df.loc[clean_df["COMMON NAME"] == "Black-bellied Plover","STATUS"] = "Migratory"
clean_df.loc[clean_df["COMMON NAME"] == "Black-crowned Night Heron","STATUS"] = "Endangered"
clean_df.loc[clean_df["COMMON NAME"] == "Double-crested Cormorant","STATUS"] = "Vulnerable"
clean_df.loc[clean_df["COMMON NAME"] == "Dunlin","STATUS"] = "Migratory"
clean_df.loc[clean_df["COMMON NAME"] == "Great Horned Owl","STATUS"] = "Stable"
clean_df.loc[clean_df["COMMON NAME"] == "Indigo Bunting","STATUS"] = "Endangered"
clean_df.loc[clean_df["COMMON NAME"] == "Northern Harrier","STATUS"] = "Endangered"
clean_df.loc[clean_df["COMMON NAME"] == "Red-Headed Woodpecker","STATUS"] = "Endangered"
clean_df.loc[clean_df["COMMON NAME"] == "Scarlet Tanager","STATUS"] = "Endangered"
clean_df.loc[clean_df["COMMON NAME"] == "Worm-eating Warbler","STATUS"] = "Endangered"

# %%
clean_df.index.name = "INDEX"

# %%
clean_df
# Out:
#                 COMMON NAME           SCIENTIFIC NAME  OBSERVATION COUNT  \
# INDEX
# 0                Bald Eagle  Haliaeetus leucocephalus                  1
# 1                Bald Eagle  Haliaeetus leucocephalus                  1
# 2                Bald Eagle  Haliaeetus leucocephalus                  1
# 3                Bald Eagle  Haliaeetus leucocephalus                  1
# 4                Bald Eagle  Haliaeetus leucocephalus                  1
# ...                     ...                       ...                ...
# 732908  Worm-eating Warbler    Helmitheros vermivorum                  1
# 732909  Worm-eating Warbler    Helmitheros vermivorum                  1
# 732910  Worm-eating Warbler    Helmitheros vermivorum                  1
# 732911  Worm-eating Warbler    Helmitheros vermivorum                  1
# 732912  Worm-eating Warbler    Helmitheros vermivorum                  1
#
#               COUNTRY     STATE    COUNTY                       LOCALITY  \
# INDEX
# ...

# %%
clean_df.to_csv("cleanbird.csv")
